# %%
from itertools import repeat
from sympy import *

# %%
init_printing()

# %%
z, x, t, n = symbols('z x t n', positive=True)
o = symbols('o0:50', commutative=False)
u = symbols('u0:50', commutative=True)

# %%
lst = 1/(1-z)

# %%
catalan = (1-sqrt(1-4*z))/(2*z)
catalan
# Out:
#     __________
# - ╲╱ -4⋅z + 1  + 1
# ──────────────────
#        2⋅z

# %%
catalan.series(z, n=10)
# Out:
#            2      3       4       5        6        7         8         9    ⎛
# 1 + z + 2⋅z  + 5⋅z  + 14⋅z  + 42⋅z  + 132⋅z  + 429⋅z  + 1430⋅z  + 4862⋅z  + O⎝
#
#  10⎞
# z  ⎠

# %%
catalan.diff(z,3).ratsimp().series(z, n=10)
# Out:
#                    2          3          4           5            6
# 30 + 336⋅z + 2520⋅z  + 15840⋅z  + 90090⋅z  + 480480⋅z  + 2450448⋅z  + 12093120
#
#   7             8              9    ⎛ 10⎞
# ⋅z  + 58198140⋅z  + 274575840⋅z  + O⎝z  ⎠

# %%
integrate(lst, (z,0,z))
# Out:
# -log(z - 1) + ⅈ⋅π

# %%
integrate(catalan, (z,0,z)).series(z,n=10)
# Out:
#      2      3      4       5               7        8         9
#     z    2⋅z    5⋅z    14⋅z       6   132⋅z    429⋅z    1430⋅z     ⎛ 10⎞
# z + ── + ──── + ──── + ───── + 7⋅z  + ────── + ────── + ─────── + O⎝z  ⎠
#     2     3      4       5              7        8         9

# %%
lst = (1/(1-z))
lst
# Out:
#   1
# ──────
# -z + 1

# %%
lst.diff(z,4).series(z,n=10)
# Out:
#                   2        3         4         5         6         7
# 24 + 120⋅z + 360⋅z  + 840⋅z  + 1680⋅z  + 3024⋅z  + 5040⋅z  + 7920⋅z  + 11880⋅z
#
# 8          9    ⎛ 10⎞
#   + 17160⋅z  + O⎝z  ⎠

# %%
5040/24
# Out:
# 210.0

# %%
((1/(1-t))*(1/(1-t**5))*(1/(1-t**10))).apart()
# Out:
#       ⎛   2          ⎞                 ⎛   2        ⎞        3       2
#     t⋅⎝2⋅t  + 2⋅t + 1⎠         (t + 1)⋅⎝2⋅t  - t + 2⎠    26⋅t  + 39⋅t  + 41⋅t
# ────────────────────────── + ───────────────────────── + ─────────────────────
#                          2      ⎛ 4    3    2        ⎞       ⎛ 4    3    2
#    ⎛ 4    3    2        ⎞    20⋅⎝t  - t  + t  - t + 1⎠   100⋅⎝t  + t  + t  + t
# 10⋅⎝t  + t  + t  + t + 1⎠
#
#
# + 34        1             77            13             1
# ───── + ────────── - ─────────── + ──────────── - ───────────
#     ⎞   40⋅(t + 1)   200⋅(t - 1)              2             3
#  + 1⎠                              100⋅(t - 1)    50⋅(t - 1)

# %% [markdown]
# ---

# %%
def multiples(z, digits=set(range(10)),degree=3):
    return sum(o[i]*z**i for i in digits)**degree

# %%
multiples(z)
# Out:
#                                                                            3
# ⎛ 9       8       7       6       5       4       3       2               ⎞
# ⎝z ⋅o₉ + z ⋅o₈ + z ⋅o₇ + z ⋅o₆ + z ⋅o₅ + z ⋅o₄ + z ⋅o₃ + z ⋅o₂ + z⋅o₁ + o₀⎠

# %%
multiples(z).series(z,n=10)
# Out:
#   3     ⎛             2           2⎞    2 ⎛     2                2
# o₀  + z⋅⎝o₀⋅o₁⋅o₀ + o₀ ⋅o₁ + o₁⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁  + o₀⋅o₂⋅o₀ + o₀ ⋅o₂ + o₁⋅o₀⋅
#
#        2           2⎞    3 ⎛                                   2
# o₁ + o₁ ⋅o₀ + o₂⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₂ + o₀⋅o₂⋅o₁ + o₀⋅o₃⋅o₀ + o₀ ⋅o₃ + o₁⋅o₀⋅o₂
#
#                 3                              2⎞    4 ⎛                2
#  + o₁⋅o₂⋅o₀ + o₁  + o₂⋅o₀⋅o₁ + o₂⋅o₁⋅o₀ + o₃⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₃ + o₀⋅o₂  + o₀
#
#                       2                                         2
# ⋅o₃⋅o₁ + o₀⋅o₄⋅o₀ + o₀ ⋅o₄ + o₁⋅o₀⋅o₃ + o₁⋅o₂⋅o₁ + o₁⋅o₃⋅o₀ + o₁ ⋅o₂ + o₂⋅o₀⋅o
#
#          2     2                                 2⎞    5 ⎛
# ₂ + o₂⋅o₁  + o₂ ⋅o₀ + o₃⋅o₀⋅o₁ + o₃⋅o₁⋅o₀ + o₄⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₄ + o₀⋅o₂⋅o₃
#
#                                      2                      2
# + o₀⋅o₃⋅o₂ + o₀⋅o₄⋅o₁ + o₀⋅o₅⋅o₀ + o₀ ⋅o₅ + o₁⋅o₀⋅o₄ + o₁⋅o₂  + o₁⋅o₃⋅o₁ + o₁⋅
#
#           2                                         2                      2
# o₄⋅o₀ + o₁ ⋅o₃ + o₂⋅o₀⋅o₃ + o₂⋅o₁⋅o₂ + o₂⋅o₃⋅o₀ + o₂ ⋅o₁ + o₃⋅o₀⋅o₂ + o₃⋅o₁  +
#
#                                        2⎞    6 ⎛                           2
#  o₃⋅o₂⋅o₀ + o₄⋅o₀⋅o₁ + o₄⋅o₁⋅o₀ + o₅⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₅ + o₀⋅o₂⋅o₄ + o₀⋅o₃  +
#
#                                     2
#  o₀⋅o₄⋅o₂ + o₀⋅o₅⋅o₁ + o₀⋅o₆⋅o₀ + o₀ ⋅o₆ + o₁⋅o₀⋅o₅ + o₁⋅o₂⋅o₃ + o₁⋅o₃⋅o₂ + o₁
#
#                       2                                                    3
# ⋅o₄⋅o₁ + o₁⋅o₅⋅o₀ + o₁ ⋅o₄ + o₂⋅o₀⋅o₄ + o₂⋅o₁⋅o₃ + o₂⋅o₃⋅o₁ + o₂⋅o₄⋅o₀ + o₂  +
#
#                                     2                      2
#  o₃⋅o₀⋅o₃ + o₃⋅o₁⋅o₂ + o₃⋅o₂⋅o₁ + o₃ ⋅o₀ + o₄⋅o₀⋅o₂ + o₄⋅o₁  + o₄⋅o₂⋅o₀ + o₅⋅o
#
#                        2⎞    7 ⎛
# ₀⋅o₁ + o₅⋅o₁⋅o₀ + o₆⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₆ + o₀⋅o₂⋅o₅ + o₀⋅o₃⋅o₄ + o₀⋅o₄⋅o₃ + o₀
#
#                                  2                                 2
# ⋅o₅⋅o₂ + o₀⋅o₆⋅o₁ + o₀⋅o₇⋅o₀ + o₀ ⋅o₇ + o₁⋅o₀⋅o₆ + o₁⋅o₂⋅o₄ + o₁⋅o₃  + o₁⋅o₄⋅o
#
#                             2
# ₂ + o₁⋅o₅⋅o₁ + o₁⋅o₆⋅o₀ + o₁ ⋅o₅ + o₂⋅o₀⋅o₅ + o₂⋅o₁⋅o₄ + o₂⋅o₃⋅o₂ + o₂⋅o₄⋅o₁ +
#
#               2                                 2                2
#  o₂⋅o₅⋅o₀ + o₂ ⋅o₃ + o₃⋅o₀⋅o₄ + o₃⋅o₁⋅o₃ + o₃⋅o₂  + o₃⋅o₄⋅o₀ + o₃ ⋅o₁ + o₄⋅o₀⋅
#
#                                                       2
# o₃ + o₄⋅o₁⋅o₂ + o₄⋅o₂⋅o₁ + o₄⋅o₃⋅o₀ + o₅⋅o₀⋅o₂ + o₅⋅o₁  + o₅⋅o₂⋅o₀ + o₆⋅o₀⋅o₁
#
#                   2⎞    8 ⎛                                      2
# + o₆⋅o₁⋅o₀ + o₇⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₇ + o₀⋅o₂⋅o₆ + o₀⋅o₃⋅o₅ + o₀⋅o₄  + o₀⋅o₅⋅o₃
#
#                                      2
# + o₀⋅o₆⋅o₂ + o₀⋅o₇⋅o₁ + o₀⋅o₈⋅o₀ + o₀ ⋅o₈ + o₁⋅o₀⋅o₇ + o₁⋅o₂⋅o₅ + o₁⋅o₃⋅o₄ + o
#
#                                              2
# ₁⋅o₄⋅o₃ + o₁⋅o₅⋅o₂ + o₁⋅o₆⋅o₁ + o₁⋅o₇⋅o₀ + o₁ ⋅o₆ + o₂⋅o₀⋅o₆ + o₂⋅o₁⋅o₅ + o₂⋅o
#
#  2                                      2
# ₃  + o₂⋅o₄⋅o₂ + o₂⋅o₅⋅o₁ + o₂⋅o₆⋅o₀ + o₂ ⋅o₄ + o₃⋅o₀⋅o₅ + o₃⋅o₁⋅o₄ + o₃⋅o₂⋅o₃
#
#                           2                                 2                2
# + o₃⋅o₄⋅o₁ + o₃⋅o₅⋅o₀ + o₃ ⋅o₂ + o₄⋅o₀⋅o₄ + o₄⋅o₁⋅o₃ + o₄⋅o₂  + o₄⋅o₃⋅o₁ + o₄
#
#                                                                   2
# ⋅o₀ + o₅⋅o₀⋅o₃ + o₅⋅o₁⋅o₂ + o₅⋅o₂⋅o₁ + o₅⋅o₃⋅o₀ + o₆⋅o₀⋅o₂ + o₆⋅o₁  + o₆⋅o₂⋅o₀
#
#                               2⎞    9 ⎛
#  + o₇⋅o₀⋅o₁ + o₇⋅o₁⋅o₀ + o₈⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₈ + o₀⋅o₂⋅o₇ + o₀⋅o₃⋅o₆ + o₀⋅o₄⋅
#
#                                                               2
# o₅ + o₀⋅o₅⋅o₄ + o₀⋅o₆⋅o₃ + o₀⋅o₇⋅o₂ + o₀⋅o₈⋅o₁ + o₀⋅o₉⋅o₀ + o₀ ⋅o₉ + o₁⋅o₀⋅o₈
#
#                              2
# + o₁⋅o₂⋅o₆ + o₁⋅o₃⋅o₅ + o₁⋅o₄  + o₁⋅o₅⋅o₃ + o₁⋅o₆⋅o₂ + o₁⋅o₇⋅o₁ + o₁⋅o₈⋅o₀ + o
#
#  2
# ₁ ⋅o₇ + o₂⋅o₀⋅o₇ + o₂⋅o₁⋅o₆ + o₂⋅o₃⋅o₄ + o₂⋅o₄⋅o₃ + o₂⋅o₅⋅o₂ + o₂⋅o₆⋅o₁ + o₂⋅o
#
#          2
# ₇⋅o₀ + o₂ ⋅o₅ + o₃⋅o₀⋅o₆ + o₃⋅o₁⋅o₅ + o₃⋅o₂⋅o₄ + o₃⋅o₄⋅o₂ + o₃⋅o₅⋅o₁ + o₃⋅o₆⋅o
#
#       3                                                            2
# ₀ + o₃  + o₄⋅o₀⋅o₅ + o₄⋅o₁⋅o₄ + o₄⋅o₂⋅o₃ + o₄⋅o₃⋅o₂ + o₄⋅o₅⋅o₀ + o₄ ⋅o₁ + o₅⋅o
#
#                        2
# ₀⋅o₄ + o₅⋅o₁⋅o₃ + o₅⋅o₂  + o₅⋅o₃⋅o₁ + o₅⋅o₄⋅o₀ + o₆⋅o₀⋅o₃ + o₆⋅o₁⋅o₂ + o₆⋅o₂⋅o
#
#                                2                                         2⎞
# ₁ + o₆⋅o₃⋅o₀ + o₇⋅o₀⋅o₂ + o₇⋅o₁  + o₇⋅o₂⋅o₀ + o₈⋅o₀⋅o₁ + o₈⋅o₁⋅o₀ + o₉⋅o₀ ⎠ +
#
#  ⎛ 10⎞
# O⎝z  ⎠

# %%
number = 3
eps = exp(2*pi*I/number)
eps
# Out:
#  2⋅ⅈ⋅π
#  ─────
#    3
# ℯ

# %%
assert 0 == sum(eps**i for i in range(number)).simplify()

# %%
s = sum(multiples(z*eps**i) for i in range(number)).expand().collect(z)

# %%
D = dict(zip(o, repeat(S.One)))
muls = sum((c/number).simplify()*z**i 
           for i in range(40) 
           for c in [s.coeff(z,i)]
           for d in [c.subs(D, simultaneous=True).radsimp()]
           if d.is_Integer)

# %%
muls
# Out:
#  27   3    24 ⎛     2                                                 3
# z  ⋅o₉  + z  ⋅⎝o₆⋅o₉  + o₇⋅o₈⋅o₉ + o₇⋅o₉⋅o₈ + o₈⋅o₇⋅o₉ + o₈⋅o₉⋅o₇ + o₈  + o₉⋅o
#
#                                2   ⎞    21 ⎛     2
# ₆⋅o₉ + o₉⋅o₇⋅o₈ + o₉⋅o₈⋅o₇ + o₉ ⋅o₆⎠ + z  ⋅⎝o₃⋅o₉  + o₄⋅o₈⋅o₉ + o₄⋅o₉⋅o₈ + o₅⋅
#
#              2                                                 2
# o₇⋅o₉ + o₅⋅o₈  + o₅⋅o₉⋅o₇ + o₆⋅o₇⋅o₈ + o₆⋅o₈⋅o₇ + o₆⋅o₉⋅o₆ + o₆ ⋅o₉ + o₇⋅o₅⋅o₉
#
#                                       3
#  + o₇⋅o₆⋅o₈ + o₇⋅o₈⋅o₆ + o₇⋅o₉⋅o₅ + o₇  + o₈⋅o₄⋅o₉ + o₈⋅o₅⋅o₈ + o₈⋅o₆⋅o₇ + o₈⋅
#
#                      2                                            2
# o₇⋅o₆ + o₈⋅o₉⋅o₄ + o₈ ⋅o₅ + o₉⋅o₃⋅o₉ + o₉⋅o₄⋅o₈ + o₉⋅o₅⋅o₇ + o₉⋅o₆  + o₉⋅o₇⋅o₅
#
#                 2   ⎞    18 ⎛     2                                         2
#  + o₉⋅o₈⋅o₄ + o₉ ⋅o₃⎠ + z  ⋅⎝o₀⋅o₉  + o₁⋅o₈⋅o₉ + o₁⋅o₉⋅o₈ + o₂⋅o₇⋅o₉ + o₂⋅o₈
#
#
# + o₂⋅o₉⋅o₇ + o₃⋅o₆⋅o₉ + o₃⋅o₇⋅o₈ + o₃⋅o₈⋅o₇ + o₃⋅o₉⋅o₆ + o₄⋅o₅⋅o₉ + o₄⋅o₆⋅o₈ +
#
#       2
#  o₄⋅o₇  + o₄⋅o₈⋅o₆ + o₄⋅o₉⋅o₅ + o₅⋅o₄⋅o₉ + o₅⋅o₆⋅o₇ + o₅⋅o₇⋅o₆ + o₅⋅o₈⋅o₅ + o₅
#
#            2
# ⋅o₉⋅o₄ + o₅ ⋅o₈ + o₆⋅o₃⋅o₉ + o₆⋅o₄⋅o₈ + o₆⋅o₅⋅o₇ + o₆⋅o₇⋅o₅ + o₆⋅o₈⋅o₄ + o₆⋅o₉
#
#         3
# ⋅o₃ + o₆  + o₇⋅o₂⋅o₉ + o₇⋅o₃⋅o₈ + o₇⋅o₄⋅o₇ + o₇⋅o₅⋅o₆ + o₇⋅o₆⋅o₅ + o₇⋅o₈⋅o₃ +
#
#              2                                                       2
# o₇⋅o₉⋅o₂ + o₇ ⋅o₄ + o₈⋅o₁⋅o₉ + o₈⋅o₂⋅o₈ + o₈⋅o₃⋅o₇ + o₈⋅o₄⋅o₆ + o₈⋅o₅  + o₈⋅o₆
#
#                               2
# ⋅o₄ + o₈⋅o₇⋅o₃ + o₈⋅o₉⋅o₁ + o₈ ⋅o₂ + o₉⋅o₀⋅o₉ + o₉⋅o₁⋅o₈ + o₉⋅o₂⋅o₇ + o₉⋅o₃⋅o₆
#
#                                                             2   ⎞    15 ⎛
#  + o₉⋅o₄⋅o₅ + o₉⋅o₅⋅o₄ + o₉⋅o₆⋅o₃ + o₉⋅o₇⋅o₂ + o₉⋅o₈⋅o₁ + o₉ ⋅o₀⎠ + z  ⋅⎝o₀⋅o₆
#
#                                                                   2
# ⋅o₉ + o₀⋅o₇⋅o₈ + o₀⋅o₈⋅o₇ + o₀⋅o₉⋅o₆ + o₁⋅o₅⋅o₉ + o₁⋅o₆⋅o₈ + o₁⋅o₇  + o₁⋅o₈⋅o₆
#
#
#  + o₁⋅o₉⋅o₅ + o₂⋅o₄⋅o₉ + o₂⋅o₅⋅o₈ + o₂⋅o₆⋅o₇ + o₂⋅o₇⋅o₆ + o₂⋅o₈⋅o₅ + o₂⋅o₉⋅o₄
#
#                              2                                      2
# + o₃⋅o₄⋅o₈ + o₃⋅o₅⋅o₇ + o₃⋅o₆  + o₃⋅o₇⋅o₅ + o₃⋅o₈⋅o₄ + o₃⋅o₉⋅o₃ + o₃ ⋅o₉ + o₄⋅
#
#                                                                             2
# o₂⋅o₉ + o₄⋅o₃⋅o₈ + o₄⋅o₅⋅o₆ + o₄⋅o₆⋅o₅ + o₄⋅o₇⋅o₄ + o₄⋅o₈⋅o₃ + o₄⋅o₉⋅o₂ + o₄ ⋅
#
#
# o₇ + o₅⋅o₁⋅o₉ + o₅⋅o₂⋅o₈ + o₅⋅o₃⋅o₇ + o₅⋅o₄⋅o₆ + o₅⋅o₆⋅o₄ + o₅⋅o₇⋅o₃ + o₅⋅o₈⋅o
#
#                  3
# ₂ + o₅⋅o₉⋅o₁ + o₅  + o₆⋅o₀⋅o₉ + o₆⋅o₁⋅o₈ + o₆⋅o₂⋅o₇ + o₆⋅o₃⋅o₆ + o₆⋅o₄⋅o₅ + o₆
#
#                                             2
# ⋅o₅⋅o₄ + o₆⋅o₇⋅o₂ + o₆⋅o₈⋅o₁ + o₆⋅o₉⋅o₀ + o₆ ⋅o₃ + o₇⋅o₀⋅o₈ + o₇⋅o₁⋅o₇ + o₇⋅o₂
#
#                       2                                      2
# ⋅o₆ + o₇⋅o₃⋅o₅ + o₇⋅o₄  + o₇⋅o₅⋅o₃ + o₇⋅o₆⋅o₂ + o₇⋅o₈⋅o₀ + o₇ ⋅o₁ + o₈⋅o₀⋅o₇ +
#
#
#  o₈⋅o₁⋅o₆ + o₈⋅o₂⋅o₅ + o₈⋅o₃⋅o₄ + o₈⋅o₄⋅o₃ + o₈⋅o₅⋅o₂ + o₈⋅o₆⋅o₁ + o₈⋅o₇⋅o₀ +
#
#                                       2                                 ⎞    1
# o₉⋅o₀⋅o₆ + o₉⋅o₁⋅o₅ + o₉⋅o₂⋅o₄ + o₉⋅o₃  + o₉⋅o₄⋅o₂ + o₉⋅o₅⋅o₁ + o₉⋅o₆⋅o₀⎠ + z
#
# 2 ⎛                                      2
#  ⋅⎝o₀⋅o₃⋅o₉ + o₀⋅o₄⋅o₈ + o₀⋅o₅⋅o₇ + o₀⋅o₆  + o₀⋅o₇⋅o₅ + o₀⋅o₈⋅o₄ + o₀⋅o₉⋅o₃ +
#
#
# o₁⋅o₂⋅o₉ + o₁⋅o₃⋅o₈ + o₁⋅o₄⋅o₇ + o₁⋅o₅⋅o₆ + o₁⋅o₆⋅o₅ + o₁⋅o₇⋅o₄ + o₁⋅o₈⋅o₃ + o
#
#                                                 2
# ₁⋅o₉⋅o₂ + o₂⋅o₁⋅o₉ + o₂⋅o₃⋅o₇ + o₂⋅o₄⋅o₆ + o₂⋅o₅  + o₂⋅o₆⋅o₄ + o₂⋅o₇⋅o₃ + o₂⋅o
#
#                     2
# ₈⋅o₂ + o₂⋅o₉⋅o₁ + o₂ ⋅o₈ + o₃⋅o₀⋅o₉ + o₃⋅o₁⋅o₈ + o₃⋅o₂⋅o₇ + o₃⋅o₄⋅o₅ + o₃⋅o₅⋅o
#
#                                                   2
# ₄ + o₃⋅o₆⋅o₃ + o₃⋅o₇⋅o₂ + o₃⋅o₈⋅o₁ + o₃⋅o₉⋅o₀ + o₃ ⋅o₆ + o₄⋅o₀⋅o₈ + o₄⋅o₁⋅o₇ +
#
#                                                                      3
#  o₄⋅o₂⋅o₆ + o₄⋅o₃⋅o₅ + o₄⋅o₅⋅o₃ + o₄⋅o₆⋅o₂ + o₄⋅o₇⋅o₁ + o₄⋅o₈⋅o₀ + o₄  + o₅⋅o₀
#
#                                                                           2
# ⋅o₇ + o₅⋅o₁⋅o₆ + o₅⋅o₂⋅o₅ + o₅⋅o₃⋅o₄ + o₅⋅o₄⋅o₃ + o₅⋅o₆⋅o₁ + o₅⋅o₇⋅o₀ + o₅ ⋅o₂
#
#                                          2                           2
#  + o₆⋅o₀⋅o₆ + o₆⋅o₁⋅o₅ + o₆⋅o₂⋅o₄ + o₆⋅o₃  + o₆⋅o₄⋅o₂ + o₆⋅o₅⋅o₁ + o₆ ⋅o₀ + o₇
#
#
# ⋅o₀⋅o₅ + o₇⋅o₁⋅o₄ + o₇⋅o₂⋅o₃ + o₇⋅o₃⋅o₂ + o₇⋅o₄⋅o₁ + o₇⋅o₅⋅o₀ + o₈⋅o₀⋅o₄ + o₈⋅
#
#              2
# o₁⋅o₃ + o₈⋅o₂  + o₈⋅o₃⋅o₁ + o₈⋅o₄⋅o₀ + o₉⋅o₀⋅o₃ + o₉⋅o₁⋅o₂ + o₉⋅o₂⋅o₁ + o₉⋅o₃⋅
#
#   ⎞    9 ⎛
# o₀⎠ + z ⋅⎝o₀⋅o₁⋅o₈ + o₀⋅o₂⋅o₇ + o₀⋅o₃⋅o₆ + o₀⋅o₄⋅o₅ + o₀⋅o₅⋅o₄ + o₀⋅o₆⋅o₃ + o₀
#
#                                  2
# ⋅o₇⋅o₂ + o₀⋅o₈⋅o₁ + o₀⋅o₉⋅o₀ + o₀ ⋅o₉ + o₁⋅o₀⋅o₈ + o₁⋅o₂⋅o₆ + o₁⋅o₃⋅o₅ + o₁⋅o₄
#
# 2                                                 2
#   + o₁⋅o₅⋅o₃ + o₁⋅o₆⋅o₂ + o₁⋅o₇⋅o₁ + o₁⋅o₈⋅o₀ + o₁ ⋅o₇ + o₂⋅o₀⋅o₇ + o₂⋅o₁⋅o₆ +
#
#                                                           2
#  o₂⋅o₃⋅o₄ + o₂⋅o₄⋅o₃ + o₂⋅o₅⋅o₂ + o₂⋅o₆⋅o₁ + o₂⋅o₇⋅o₀ + o₂ ⋅o₅ + o₃⋅o₀⋅o₆ + o₃
#
#                                                        3
# ⋅o₁⋅o₅ + o₃⋅o₂⋅o₄ + o₃⋅o₄⋅o₂ + o₃⋅o₅⋅o₁ + o₃⋅o₆⋅o₀ + o₃  + o₄⋅o₀⋅o₅ + o₄⋅o₁⋅o₄
#
#                                       2                                 2
#  + o₄⋅o₂⋅o₃ + o₄⋅o₃⋅o₂ + o₄⋅o₅⋅o₀ + o₄ ⋅o₁ + o₅⋅o₀⋅o₄ + o₅⋅o₁⋅o₃ + o₅⋅o₂  + o₅
#
#
# ⋅o₃⋅o₁ + o₅⋅o₄⋅o₀ + o₆⋅o₀⋅o₃ + o₆⋅o₁⋅o₂ + o₆⋅o₂⋅o₁ + o₆⋅o₃⋅o₀ + o₇⋅o₀⋅o₂ + o₇⋅
#
#   2                                         2⎞    6 ⎛
# o₁  + o₇⋅o₂⋅o₀ + o₈⋅o₀⋅o₁ + o₈⋅o₁⋅o₀ + o₉⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₅ + o₀⋅o₂⋅o₄ + o₀⋅
#
#   2                                      2
# o₃  + o₀⋅o₄⋅o₂ + o₀⋅o₅⋅o₁ + o₀⋅o₆⋅o₀ + o₀ ⋅o₆ + o₁⋅o₀⋅o₅ + o₁⋅o₂⋅o₃ + o₁⋅o₃⋅o₂
#
#                            2
#  + o₁⋅o₄⋅o₁ + o₁⋅o₅⋅o₀ + o₁ ⋅o₄ + o₂⋅o₀⋅o₄ + o₂⋅o₁⋅o₃ + o₂⋅o₃⋅o₁ + o₂⋅o₄⋅o₀ +
#
#   3                                      2                      2
# o₂  + o₃⋅o₀⋅o₃ + o₃⋅o₁⋅o₂ + o₃⋅o₂⋅o₁ + o₃ ⋅o₀ + o₄⋅o₀⋅o₂ + o₄⋅o₁  + o₄⋅o₂⋅o₀ +
#
#                             2⎞    3 ⎛                                   2
#  o₅⋅o₀⋅o₁ + o₅⋅o₁⋅o₀ + o₆⋅o₀ ⎠ + z ⋅⎝o₀⋅o₁⋅o₂ + o₀⋅o₂⋅o₁ + o₀⋅o₃⋅o₀ + o₀ ⋅o₃ +
#
#                          3                              2⎞     3
#  o₁⋅o₀⋅o₂ + o₁⋅o₂⋅o₀ + o₁  + o₂⋅o₀⋅o₁ + o₂⋅o₁⋅o₀ + o₃⋅o₀ ⎠ + o₀

# %%
muls.subs(dict(zip(o, u)))
# Out:
#   3     3  27    24 ⎛       2                  3⎞    21 ⎛       2
# u₀  + u₉ ⋅z   + z  ⋅⎝3⋅u₆⋅u₉  + 6⋅u₇⋅u₈⋅u₉ + u₈ ⎠ + z  ⋅⎝3⋅u₃⋅u₉  + 6⋅u₄⋅u₈⋅u₉
#
#                        2       2                     3⎞    18 ⎛       2
#  + 6⋅u₅⋅u₇⋅u₉ + 3⋅u₅⋅u₈  + 3⋅u₆ ⋅u₉ + 6⋅u₆⋅u₇⋅u₈ + u₇ ⎠ + z  ⋅⎝3⋅u₀⋅u₉  + 6⋅u₁
#
#                              2
# ⋅u₈⋅u₉ + 6⋅u₂⋅u₇⋅u₉ + 3⋅u₂⋅u₈  + 6⋅u₃⋅u₆⋅u₉ + 6⋅u₃⋅u₇⋅u₈ + 6⋅u₄⋅u₅⋅u₉ + 6⋅u₄⋅u
#
#               2       2                     3⎞    15 ⎛
# ₆⋅u₈ + 3⋅u₄⋅u₇  + 3⋅u₅ ⋅u₈ + 6⋅u₅⋅u₆⋅u₇ + u₆ ⎠ + z  ⋅⎝6⋅u₀⋅u₆⋅u₉ + 6⋅u₀⋅u₇⋅u₈
#
#                                    2
# + 6⋅u₁⋅u₅⋅u₉ + 6⋅u₁⋅u₆⋅u₈ + 3⋅u₁⋅u₇  + 6⋅u₂⋅u₄⋅u₉ + 6⋅u₂⋅u₅⋅u₈ + 6⋅u₂⋅u₆⋅u₇ +
#
#     2                                       2       2                     3⎞
# 3⋅u₃ ⋅u₉ + 6⋅u₃⋅u₄⋅u₈ + 6⋅u₃⋅u₅⋅u₇ + 3⋅u₃⋅u₆  + 3⋅u₄ ⋅u₇ + 6⋅u₄⋅u₅⋅u₆ + u₅ ⎠ +
#
#   12 ⎛                                              2
#  z  ⋅⎝6⋅u₀⋅u₃⋅u₉ + 6⋅u₀⋅u₄⋅u₈ + 6⋅u₀⋅u₅⋅u₇ + 3⋅u₀⋅u₆  + 6⋅u₁⋅u₂⋅u₉ + 6⋅u₁⋅u₃⋅u
#
#                                   2                                       2
# ₈ + 6⋅u₁⋅u₄⋅u₇ + 6⋅u₁⋅u₅⋅u₆ + 3⋅u₂ ⋅u₈ + 6⋅u₂⋅u₃⋅u₇ + 6⋅u₂⋅u₄⋅u₆ + 3⋅u₂⋅u₅  +
#
#     2                     3⎞    9 ⎛    2
# 3⋅u₃ ⋅u₆ + 6⋅u₃⋅u₄⋅u₅ + u₄ ⎠ + z ⋅⎝3⋅u₀ ⋅u₉ + 6⋅u₀⋅u₁⋅u₈ + 6⋅u₀⋅u₂⋅u₇ + 6⋅u₀⋅u
#
#                         2                                       2       2
# ₃⋅u₆ + 6⋅u₀⋅u₄⋅u₅ + 3⋅u₁ ⋅u₇ + 6⋅u₁⋅u₂⋅u₆ + 6⋅u₁⋅u₃⋅u₅ + 3⋅u₁⋅u₄  + 3⋅u₂ ⋅u₅ +
#
#                 3⎞    6 ⎛    2                                       2       2
#  6⋅u₂⋅u₃⋅u₄ + u₃ ⎠ + z ⋅⎝3⋅u₀ ⋅u₆ + 6⋅u₀⋅u₁⋅u₅ + 6⋅u₀⋅u₂⋅u₄ + 3⋅u₀⋅u₃  + 3⋅u₁
#
#                      3⎞    3 ⎛    2                     3⎞
# ⋅u₄ + 6⋅u₁⋅u₂⋅u₃ + u₂ ⎠ + z ⋅⎝3⋅u₀ ⋅u₃ + 6⋅u₀⋅u₁⋅u₂ + u₁ ⎠

# %%
muls.subs(dict(zip(o, repeat(1))))
# Out:
#  27       24       21       18       15       12       9       6       3
# z   + 10⋅z   + 28⋅z   + 55⋅z   + 73⋅z   + 73⋅z   + 55⋅z  + 28⋅z  + 10⋅z  + 1

# %%
s = _.coeff(z,8)
s.radsimp()
# Out:
# 0

# %%
_.simplify()
# Out:
# ⎛    3 ____       2/3⎞     4
# ⎝1 - ╲╱ -1  + (-1)   ⎠⋅o[2]

# %%
_.powsimp()
# Out:
# ⎛    3 ____       2/3⎞     4
# ⎝1 - ╲╱ -1  + (-1)   ⎠⋅o[2]
